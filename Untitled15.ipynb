# %% [markdown]
# <a href="https://colab.research.google.com/github/sivavasudevan601-arch/code/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=(input("Enter your name"))
age=int(input("Enter your age"))
salary=int(input("Enter your salary"))
print("Name:",name)
print("Age:",age)
print("Salary:",salary)
# Out:
# Enter your namesiva
# Enter your age21
# Enter your salary30000
# Name: siva
# Age: 21
# Salary: 30000
